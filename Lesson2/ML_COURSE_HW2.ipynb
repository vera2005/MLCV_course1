# %% [markdown]
# <a href="https://colab.research.google.com/github/vera2005/MLCV_course1/blob/main/Lesson2/ML_COURSE_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задача 1
#
# В этом задании вы примените линейную регрессию к задаче компьютерного зрения. Вы будете работать с датасетом изображений лиц Olivetti Faces и научитесь предсказывать среднюю яркость изображения по его пикселям.

# %% [markdown]
# План
# 1) Загрузить датасет Olivetti Faces (встроен в sklearn)
#
# 2) Вычислить для каждого изображения целевую переменную - среднюю яркость
#
# 3) Обучить модель линейной регрессии предсказывать яркость по пикселям
#
# 4) Визуализировать результаты: показать изображения с реальной и предсказанной яркостью
#
# 5) Оценить качество модели с помощью функций потерь

# %% [markdown]
# 0) омпорт библиотек

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.datasets import fetch_olivetti_faces
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1) Загрузка датасета

# %%
print("Загрузка датасета Olivetti Faces...")
faces = fetch_olivetti_faces()
X = faces.data
images = faces.images

# Вычисляем целевую переменную - среднюю яркость каждого изображения
y = np.mean(images, axis=(1, 2))

print("Количество изображений:", X.shape[0])
print("Размер изображения:", images[0].shape)
print("Размер вектора признаков (пикселей):", X.shape[1])
print("Диапазон яркости от", round(y.min(), 3), "до", round(y.max(), 3))
# Out:
# Загрузка датасета Olivetti Faces...
# Количество изображений: 400
# Размер изображения: (64, 64)
# Размер вектора признаков (пикселей): 4096
# Диапазон яркости от 0.382 до 0.725

# %% [markdown]
# 2) Демонстрация образцов из датасета с указанием значения целевой переменной

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for i in range(10):
    idx = np.random.randint(0, len(X))
    axes[i//5, i%5].imshow(images[idx], cmap='gray')
    axes[i//5, i%5].set_title('Яркость: ' + str(round(y[idx], 3)))
    axes[i//5, i%5].axis('off')
plt.suptitle('Примеры изображений с целевой меткой (средняя яркость)')
plt.tight_layout()
plt.show()

# %% [markdown]
# 3) Разделите датасет на обучающую и тестовую выборки: X_train, X_test, y_train, y_test

# %%
# Out:
# Обучающая выборка: 320 изображений
# Тестовая выборка: 80 изображений

# %% [markdown]
# 4) Обучение модели линейной регрессии

# %%
# Out:
# Модель обучена

# %% [markdown]
# 5) Демонстрация результатов обучения: изображение, предсказание, правильный ответ

# %%
# Выбираем 5 случайных изображений из тестовой выборки
indices = np.random.choice(len(X_test), 5, replace=False)

fig, axes = plt.subplots(1, 5, figsize=(15, 4))
for i, idx in enumerate(indices):
    # Получаем предсказание для этого изображения
    pred = model.predict(X_test[idx].reshape(1, -1))[0]
    real = y_test[idx]

    # Отображаем изображение
    axes[i].imshow(X_test[idx].reshape(64, 64), cmap='gray')
    axes[i].set_title('Реальная: ' + str(round(real, 3)) +
                     '\nПредсказанная: ' + str(round(pred, 3)))
    axes[i].axis('off')
plt.suptitle('Сравнение предсказаний модели с реальными значениями')
plt.tight_layout()
plt.show()

# %% [markdown]
# 6) Оценка качества модели
#
# С помощью метода predict определите предсказания модели на всей тестовой выборке, после этого вычислите метрику MSE, RMSE, MAE

# %%
# Out:
# ...
# ОЦЕНКА КАЧЕСТВА МОДЕЛИ
# ...
# MSE (среднеквадратичная ошибка): 0.0
# RMSE (корень из MSE): 0.000181
# MAE (средняя абсолютная ошибка): 0.000136
# R2 (коэффициент детерминации): 1.0
# ...

# %%
print("=" * 50)
print("ОЦЕНКА КАЧЕСТВА МОДЕЛИ")
print("=" * 50)
print("MSE (среднеквадратичная ошибка):", round(mse, 6))
print("RMSE (корень из MSE):", round(rmse, 6))
print("MAE (средняя абсолютная ошибка):", round(mae, 6))

# %% [markdown]
# 7) Визуализация худших и лучших предсказаний

# %%
errors_abs = np.abs(y_pred - y_test)
best_idx = np.argsort(errors_abs)[:5]
worst_idx = np.argsort(errors_abs)[-5:]

fig, axes = plt.subplots(1, 5, figsize=(15, 4))
for i, idx in enumerate(best_idx):
    axes[i].imshow(X_test[idx].reshape(64, 64), cmap='gray')
    axes[i].set_title('Реал: ' + str(round(y_test[idx], 3)) +
                     '\nПред: ' + str(round(y_pred[idx], 3)))
    axes[i].axis('off')
plt.suptitle('Лучшие предсказания (минимальная ошибка)')
plt.tight_layout()
plt.show()

fig, axes = plt.subplots(1, 5, figsize=(15, 4))
for i, idx in enumerate(worst_idx):
    axes[i].imshow(X_test[idx].reshape(64, 64), cmap='gray')
    axes[i].set_title('Реал: ' + str(round(y_test[idx], 3)) +
                     '\nПред: ' + str(round(y_pred[idx], 3)))
    axes[i].axis('off')
plt.suptitle('Худшие предсказания (максимальная ошибка)')
plt.tight_layout()
plt.show()

# %% [markdown]
# 8) Напишите код, который строит график сравнения предсказанных и реальных значений целевой переменной на тестовой выборке.
#
# 1)Создайте новый график с размерами 10x6 дюймов
#
# 2) Нанесите точки, где:
#
# По оси X — реальные значения (y_test)
#
# По оси Y — предсказанные значения (y_pred)
#
# 3) Точки должны быть полупрозрачными (alpha=0.5)
#
# 4) Добавьте пунктирную красную линию, проходящую от минимального до максимального значения. Эта линия показывает, где точки должны находиться при идеальном предсказании.
#
# 5) Подпишите оси:
#
# X: "Реальная яркость"
#
# Y: "Предсказанная яркость"
#
# Добавьте заголовок: "Сравнение предсказанных и реальных значений"
#
# 6) Включите сетку с прозрачностью 0.3
#
# 7) Отобразите график

# %%
print("\n" + "=" * 50)
print("ВЫВОДЫ")
print("=" * 50)
print("1. Модель предсказывает яркость с R2 =", round(r2, 4))
print("2. Средняя ошибка (MAE):", round(mae, 6))
print("3. RMSE:", round(rmse, 6))
print("4. Худшие предсказания часто у изображений с нестандартным освещением")
print("5. Линейная регрессия - простой, но эффективный инструмент для CV-задач")
print("=" * 50)
