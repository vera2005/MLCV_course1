# %% [markdown]
# <a href="https://colab.research.google.com/github/vera2005/MLCV_course1/blob/main/Lesson2/ML_COURSE_Lesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Подключаем отображение графиков прямо в ноутбуке
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# Для библиотечной регрессии
from sklearn.linear_model import SGDRegressor

# Для нейросетевой реализации (Keras)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# Зафиксируем генератор случайных чисел для воспроизводимости
np.random.seed(42)
tf.random.set_seed(42)

print("Библиотеки загружены, всё готово!")

# %% [markdown]
# Ручная реализация градиентного спуска на примере простой функции одной переменной
# f(x) = x**2

# %%
# Определяем функцию и её производную

# Параметры спуска (начальное значение, скорость обучения, число эпох)


# Сохраняем историю для визуализации
history_x = [x]
history_f = [f(x)]

# Реализация градиентного спуска


print(f"\nМинимум достигнут при x = {x:.6f}, f(x) = {f(x):.6f}")

# %%
# Визуализация траектории движения
x_vals = np.linspace(-11, 11, 200)
plt.figure(figsize=(8, 5))
plt.plot(x_vals, f(x_vals), label='f(x) = x²', color='blue')
plt.scatter(history_x, history_f, c='red', s=30, label='Траектория спуска')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Градиентный спуск для параболы')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Генерация данных для линейной регрессии
#
# Создаем синтетический датасет, который имитирует задачу компьютерного зрения: предсказание глубины сцены по яркости пикселя.

# %%
# Генерируем 100 точек: X – средняя яркость (0..10), y – глубина (линейная зависимость + шум)
X = np.random.rand(100, 1) * 10          # яркость
y = 2.0 * X + 5.0 + np.random.randn(100, 1) * 0.5   # глубина = 2*яркость + 5 + шум

# Визуализируем данные
plt.figure(figsize=(8, 5))
plt.scatter(X, y, alpha=0.7, label='Данные')
plt.xlabel("Средняя яркость пикселя (усл. ед.)")
plt.ylabel("Глубина сцены (усл. ед.)")
plt.title("Задача: предсказание глубины по яркости")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2835/4234110786.py in <cell line: 0>()
#       1 # Генерируем 100 точек: X – средняя яркость (0..10), y – глубина (линейная зависимость + шум)
# ----> 2 X = np.random.rand(100, 1) * 10          # яркость
#       3 y = 2.0 * X + 5.0 + np.random.randn(100, 1) * 0.5   # глубина = 2*яркость + 5 + шум
#       4
#       5 # Визуализируем данные
#
# NameError: name 'np' is not defined

# %% [markdown]
# Ручная реализация алгоритма линейной регрессии для поиска прямой, описывающей синтезированный данные

# %%
from IPython.display import clear_output

# Инициализация параметров
w = np.random.randn(1)
b = np.random.randn(1)
print(f"Начальные параметры: w = {w[0]:.6f}, b = {b[0]:.6f}")
# Запоминаем начальные параметры для отображения на графике
w0, b0 = w.copy(), b.copy()

# %% [markdown]
# Инициализируем гиперпараметры: скорость обучения, число эпох, history

# %% [markdown]
# линейная регрессия: предсказание, расчет градиентов, обновление параметров

# %%
plt.figure(figsize=(8, 5))

#линейная регрессия


    # Каждые interval эпох – визуализация
    if epoch % interval == 0:
        clear_output(wait=True)  # очищаем вывод в текущей ячейке

        # Текущая прямая
        x_line = np.linspace(0, 10, 100).reshape(-1, 1)
        y_line = x_line * w + b

        # Рисуем данные и текущую прямую
        plt.scatter(X, y, alpha=0.6, label='Данные')
        plt.plot(x_line, y_line, color='red', linewidth=2, label=f'Эпоха {epoch}')
        plt.xlabel("Средняя яркость")
        plt.ylabel("Глубина")
        plt.title(f"Обучение нейрона (эпоха {epoch}, Loss = {loss:.4f})")
        plt.grid(True)
        plt.legend()
        plt.xlim(0, 10)
        plt.ylim(0, 25)  # подберите под свои данные
        plt.show()

        # Вывод текущих параметров
        print(f"Эпоха {epoch:3d}: w = {w[0]:.6f}, b = {b[0]:.6f}, Loss = {loss:.6f}")

# %%
# Финальный результат
clear_output(wait=True)
print(f"\nОбучение завершено!\nИтоговые параметры: w = {w[0]:.6f}, b = {b[0]:.6f}")
print(f"Реальные значения: w = 2.000000, b = 5.000000\n")

# Финальный график
x_line = np.linspace(0, 10, 100).reshape(-1, 1)
y_line = x_line * w + b

plt.scatter(X, y, alpha=0.6, label='Данные')
plt.plot(x_line, y_line, color='red', linewidth=3, label='Финальная прямая')
plt.xlabel("Средняя яркость")
plt.ylabel("Глубина")
plt.title("Результат ручного градиентного спуска")
plt.grid(True)
plt.legend()
plt.xlim(0, 10)
plt.ylim(0, 25)
plt.show()

# %%
# Строим предсказанную линию
x_line = np.linspace(0, 10, 100).reshape(-1, 1)
y_line = x_line * w + b

plt.figure(figsize=(8, 5))
plt.scatter(X, y, alpha=0.7, label='Данные')
plt.plot(x_line, y_line, color='red', linewidth=2, label='Обученная прямая')
plt.xlabel("Средняя яркость")
plt.ylabel("Глубина")
plt.title("Результат ручного градиентного спуска")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Реализация линейной регрессии по человечески: через библиотеку kerras

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %% [markdown]
# Создание и обучение модели

# %%
# Извлекаем веса
w_keras, b_keras = model.layers[0].get_weights()
w_keras = w_keras[0][0]
b_keras = b_keras[0]
print(f"Keras: w = {w_keras:.6f}, b = {b_keras:.6f}")

# %%
# Финальная визуализация
x_line = np.linspace(0, 10, 100).reshape(-1, 1)
y_line = x_line * w_keras + b_keras

plt.figure(figsize=(8, 5))
plt.scatter(X, y, alpha=0.6, label='Данные')
plt.plot(x_line, y_line, color='red', linewidth=3, label='Keras (1 нейрон)')
plt.xlabel("Средняя яркость")
plt.ylabel("Глубина")
plt.title("Результат библиотечной реализации (Keras)")
plt.grid(True)
plt.legend()
plt.xlim(0, 10)
plt.ylim(0, 25)
plt.show()

# %% [markdown]
# Реальная задачка на реальном датасете
# Применим линейную регрессию к реальному датасету **California Housing** — это классическая задача машинного обучения: **предсказать стоимость дома** на основе различных характеристик района.

# %% [markdown]
# 1. **Загрузим** датасет California Housing (встроен в `sklearn`);
# 2. **Разделим** данные на обучающую (80%) и тестовую (20%) выборки;
# 3. **Обучим** модель линейной регрессии на обучающих данных;
# 4. **Оценим качество** модели на тестовых данных с помощью метрик:
#    - **MSE** (среднеквадратичная ошибка) — показывает, насколько сильно мы ошибаемся в долларах (в квадрате);
# 5. **Визуализируем** предсказания: сравним реальные и предсказанные цены на графике.

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Загрузка данных и разделение на обучающую и тестовую выборки

# %% [markdown]
# Обучение модели

# %% [markdown]
# Предсказание на тесте и оценка качества

# %%
print(f"Коэффициенты (веса): {lr.coef_}")
print(f"Смещение (intercept): {lr.intercept_}")
print(f"MSE на тесте: {mse:.4f}")

# Визуализация: предсказанные vs реальные значения
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', linewidth=2)
plt.xlabel("Реальные значения")
plt.ylabel("Предсказанные значения")
plt.title("Линейная регрессия на California Housing")
plt.grid(True)
plt.show()
